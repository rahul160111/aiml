# %%
import matplotlib 

print(matplotlib.__version__)
# Out:
# 3.11.0

# %%
import matplotlib.pyplot as plt 
import numpy as np 

xpoint = np.array([0,6])
ypoint = np.array([0,250])

plt.plot(xpoint,ypoint,'x')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 

xpoint = np.array([1,2,6,10])
ypoint = np.array([3,8,1,10])

plt.plot(xpoint,ypoint,'o')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 

ypoint = np.array([3,10,5,8,2,6])

plt.plot(ypoint,marker='D')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 

ypoint = np.array([3,10,5,8,2,6])

plt.plot(ypoint,'-.k')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 

ypoint = np.array([3,10,5,8,2,6])

plt.plot(ypoint,linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 

xpoint = np.array([3,10,5,8,2,6])
ypoint = np.array([2,5,2,4,6,3])

plt.plot(xpoint,ypoint)

plt.xlabel("average Pluse")
plt.ylabel("calories Burnage")
plt.show()

# %%
import matplotlib.pyplot as pt 
import numpy as np 

x = np.array([2,4,6,8])
y = np.array([1,3,5,7])

plt.plot(x,y)
plt.xlabel('movie')
plt.ylabel('year')
plt.show()

# %%
import matplotlib.pyplot as pt
import numpy as np 

x = np.array([2,6,8,9])
y = np.array([3,5,7,9])

pt.plot(x,y)
pt.xlabel('game')
pt.ylabel('pubg')

pt.show()

# %%
import matplotlib.pyplot as pt 
import numpy as np 
 
x = ([10,30,50,60])
y = ([20,40,60,80])

pt.plot(x,y) 
pt.ylabel
pt.xlabel('marker')
pt.ylabel('point')
pt.grid()
pt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 

a = np.array([ i for i in range (1,20)])
b = np.array([ i for i in range (21,40)])

plt.scatter(a,b)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()
